# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
from torchvision import models
from torch.autograd import Function
from torch.autograd import Variable
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
torch.manual_seed(42)
np.random.seed(42)

# %%
# %cd 'drive/My Drive/ACV Project/'
# Out:
# /content/drive/.shortcut-targets-by-id/1-uBPm49Eo3uaCU1aA2S0UwaL0_iMXQKS/ACV Project

# %%
dim = 64
X = np.load(f'./Dataset-{dim}/TR-Image.npy')
y = np.load(f'./Dataset-{dim}/TR-Mask.npy')

X_test = np.load(f'./Dataset-{dim}/TE-Image.npy')
y_test = np.load(f'./Dataset-{dim}/TE-Mask.npy')

# %%
print(y.max(), y.min(), np.unique(y))
# Out:
# 1 0 [0 1]

# %%
print(X.shape, X.dtype, X.max(), X.min())
# Out:
# (10553, 64, 64, 3) uint8 255 0

# %%
num_train = int(len(X) * 0.8)

p = np.random.permutation(len(X))
X = X[p]
y = y[p]

X_train, X_val = X[ : num_train], X[num_train : ]
y_train, y_val = y[ : num_train], y[num_train : ]

# %%
print(X_train.shape, X_val.shape)
print(y_train.shape, y_val.shape)
# Out:
# (8442, 64, 64, 3) (2111, 64, 64, 3)
# (8442, 64, 64) (2111, 64, 64)

# %%
class CustomDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.transform = transform
        self.images = images
        self.labels = labels

    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):
        img, lab = self.images[idx], self.labels[idx]
        if self.transform:
            img = self.transform(img).type(torch.FloatTensor)
        
        lab = torch.from_numpy(lab).type(torch.LongTensor)
        return (img, lab)

# %%
transform = transforms.Compose(
    [
     transforms.ToTensor(),
    ]
)

# %%
train_set = CustomDataset(X_train, y_train, transform=transform)
val_set = CustomDataset(X_val, y_val, transform=transform)
test_set = CustomDataset(X_test, y_test, transform=transform)

# %%
train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=32, shuffle=True)
test_loader = DataLoader(test_set, batch_size=32, shuffle=True)

# %%
itr = iter(train_loader)
img, lab = next(itr)

print(img.size(), lab.size())
print(img.type(), lab.type())
# Out:
# torch.Size([32, 3, 64, 64]) torch.Size([32, 64, 64])
# torch.FloatTensor torch.LongTensor

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()

        # 64x64
        self.conv1 = nn.Conv2d(3, 64, kernel_size = (3, 3), stride = 1, padding = 1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 64, kernel_size = (3, 3), stride = 1, padding = 1)
        self.bn2 = nn.BatchNorm2d(64)
        self.pool1 = nn.MaxPool2d(kernel_size = 2, stride = 2)

        #32x32
        self.conv3 = nn.Conv2d(64, 128, kernel_size = (3, 3), stride = 1, padding = 1)
        self.bn3 = nn.BatchNorm2d(128)
        self.conv4 = nn.Conv2d(128, 128, kernel_size = (3, 3), stride = 1, padding = 1)
        self.bn4 = nn.BatchNorm2d(128)
        self.pool2 = nn.MaxPool2d(kernel_size = 2, stride = 2)
        self.drop1 = nn.Dropout()

        #16x16
        self.conv5 = nn.Conv2d(128, 128, kernel_size = (3, 3), stride = 1, padding = 1)
        self.bn5 = nn.BatchNorm2d(128)
        self.conv6 = nn.Conv2d(128, 128, kernel_size = (3, 3), stride = 1, padding = 1)
        self.bn6 = nn.BatchNorm2d(128)
        self.pool3 = nn.MaxPool2d(kernel_size = 2, stride = 2)
        self.drop2 = nn.Dropout()

        #8x8
        self.upconv1 = nn.ConvTranspose2d(128, 128, kernel_size = 2, stride = 2)
        self.bn7 = nn.BatchNorm2d(128)
        #16x16
        self.upconv2 = nn.ConvTranspose2d(128, 64, kernel_size = 2, stride = 2)
        self.bn8 = nn.BatchNorm2d(64)
        #32x32
        self.upconv3 = nn.ConvTranspose2d(64, 2, kernel_size = 2, stride = 2)
        #64x64

        self.upscore1 = nn.Upsample(scale_factor=8,mode='bilinear')
        self.upscore2 = nn.Upsample(scale_factor=4,mode='bilinear')
        self.upscore3 = nn.Upsample(scale_factor=2,mode='bilinear')

        self.outconv1 = nn.Conv2d(128,2,3,padding=1)
        self.outconv2 = nn.Conv2d(128,2,3,padding=1)
        self.outconv3 = nn.Conv2d(64,2,3,padding=1)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x1 = self.pool1(x)
        

        x = F.relu(self.bn3(self.conv3(x1)))
        x = F.relu(self.bn4(self.conv4(x)))
        x2 = self.pool2(x)
        x = self.drop1(x2)

        x = F.relu(self.bn5(self.conv5(x)))
        x = F.relu(self.bn6(self.conv6(x)))
        x3 = self.pool3(x)

        x4 = F.relu(self.bn7(self.upconv1(self.drop2(x3))))
        x5 = F.relu(self.bn8(self.upconv2(x4 + x2)))
        x6 = self.upconv3(x5 + x1)

        return self.upscore1(self.outconv1(x3)), self.upscore2(self.outconv2(x4)), self.upscore3(self.outconv3(x5)), x6

# %%
class RefineNet(nn.Module):

    def __init__(self):
        super(RefineNet, self).__init__()

        # 64x64
        self.conv1 = nn.Conv2d(2, 64, kernel_size = (3, 3), stride = 1, padding = 1)
        self.bn1 = nn.BatchNorm2d(64)
        self.pool1 = nn.MaxPool2d(kernel_size = 2, stride = 2)

        #32x32
        self.conv2 = nn.Conv2d(64, 128, kernel_size = (3, 3), stride = 1, padding = 1)
        self.bn2 = nn.BatchNorm2d(128)
        self.pool2 = nn.MaxPool2d(kernel_size = 2, stride = 2)
        self.drop1 = nn.Dropout()

        #16x16
        self.upconv1 = nn.ConvTranspose2d(128, 64, kernel_size = 2, stride = 2)
        self.bn3 = nn.BatchNorm2d(64)
        #32x32
        self.upconv2 = nn.ConvTranspose2d(64, 2, kernel_size = 2, stride = 2)
        #64x64

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = self.pool1(x)
        

        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool2(x)
        x = self.drop1(x)

        x = F.relu(self.bn3(self.upconv1(x)))
        x = self.upconv2(x)

        return x

# %%
model = Net().to(device)
refine_model = RefineNet().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
refine_optimizer = optim.Adam(refine_model.parameters())

# %%
def IoULoss(predicted, ground_truth):

    intersect = (predicted * ground_truth).sum((1, 2))
    union = (predicted + ground_truth).clamp(0, 1).sum((1, 2))

    return (1 - (intersect / union)).mean()

# %%
def train(model, refine_model, train_loader):
    model.train()
    refine_model.train()
    
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data[0].to(device), data[1].to(device)

        optimizer.zero_grad()
        refine_optimizer.zero_grad()

        outputs1, outputs2, outputs3, outputs4 = model(inputs)

        loss1 = criterion(outputs1, labels) + IoULoss(outputs1.max(dim=1)[1], labels)
        loss2 = criterion(outputs2, labels) + IoULoss(outputs2.max(dim=1)[1], labels)
        loss3 = criterion(outputs3, labels) + IoULoss(outputs3.max(dim=1)[1], labels)
        loss4 = criterion(outputs4, labels) + IoULoss(outputs4.max(dim=1)[1], labels)
        
        outputs5 = refine_model(outputs4)
        
        loss5 = criterion(outputs5, labels) + IoULoss(outputs5.max(dim=1)[1], labels)
        
        loss = 4*loss1 + 3*loss2 + 2*loss3 + loss4 + loss5

        running_loss += loss.item()
        loss.backward()
        refine_optimizer.step()
        optimizer.step()

        if i % 50 == 49:
            print(f'Iteration {i + 1:5} | { (running_loss / 50):.5f}')
            running_loss = 0.0

# %%
def accuracy(model, refine_model, dataloader):
    model.eval()
    refine_model.eval()

    correct = 0
    total = 0
    iters = 0
    running_loss = 0

    with torch.no_grad():
        for data in dataloader:
            images, labels = data[0].to(device), data[1].to(device)
            _,_,_,outputs = model(images)
            outputs = refine_model(outputs)
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += (labels.size(0) * labels.size(1) * labels.size(2))
            correct += (predicted == labels).sum().item()
            iters += 1

    print('Accuracy of the network on the images: %.3f %%' % (100 * correct / total))
    return (running_loss / iters), (100 * correct / total)

# %%
def mIoU(model, refine_model, dataloader, n_classes):
    model.eval()
    refine_model.eval()

    intersection = [0 for i in range(n_classes)]
    union = [0 for i in range(n_classes)]

    with torch.no_grad():
        for data in dataloader:
            images, labels = data[0].to(device), data[1].to(device)
            _,_,_,outputs = model(images)
            outputs = refine_model(outputs)
            _, predicted = torch.max(outputs, 1)

            for i in range(n_classes):
                intersect = torch.mul(predicted==i, labels==i).sum().item()
                uni = torch.add(predicted==i, labels==i).sum().item()
                intersection[i] += intersect
                union[i] += uni

    iou = [0 for i in range(n_classes)]
    for i in range(n_classes):
        iou[i] = intersection[i] / union[i]
    
    return sum(iou) / len(iou)

# %%
start = 0
epochs = 100
train_acc = []
train_loss = []
val_acc = []
val_loss = []

for epoch in range(start, start + epochs):
    print(f'Epoch {epoch + 1} started')
    train(model, refine_model, train_loader)

    print('IOU Train', mIoU(model, refine_model, train_loader, 2))
    print('IOU val', mIoU(model, refine_model, val_loader, 2))

    loss, acc = accuracy(model, refine_model, train_loader)
    train_acc.append(acc)
    train_loss.append(loss)
    loss, acc = accuracy(model, refine_model, val_loader)
    val_acc.append(acc)
    val_loss.append(loss)

    PATH = './CustomNet-64-v4-refinenet/' + str(epoch + 1)
    torch.save(model, PATH)

    PATH += '-checkpoint'
    torch.save({
        'epoch': epoch+1,
        'model-state-dict': model.state_dict(),
        'refinemodel-state-dict': refine_model.state_dict(),
        'train_acc': train_acc,
        'train_loss': train_loss,
        'val_acc': val_acc,
        'val_loss': val_loss
    }, PATH)
# Out:
# Epoch 1 started
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3063: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# Iteration    50 | 12.03789
# Iteration   100 | 9.89243
# Iteration   150 | 9.25091
# Iteration   200 | 8.93741
# Iteration   250 | 8.70801
# IOU Train 0.7067158051911466
# IOU val 0.70392077295124
# Accuracy of the network on the images: 86.238 %
# Accuracy of the network on the images: 86.074 %
# Epoch 2 started
# Iteration    50 | 8.27459
# Iteration   100 | 8.02248
# Iteration   150 | 7.75066
# Iteration   200 | 7.70298
# Iteration   250 | 7.44181
# IOU Train 0.7433361299606123
# IOU val 0.7356287021984538
# Accuracy of the network on the images: 87.888 %
# Accuracy of the network on the images: 87.449 %
# Epoch 3 started
# Iteration    50 | 7.38104
# Iteration   100 | 7.27064
# Iteration   150 | 6.95697
# Iteration   200 | 7.01410
# Iteration   250 | 7.04310
# IOU Train 0.7583041872806648
# IOU val 0.754016909489954
# Accuracy of the network on the images: 89.166 %
# Accuracy of the network on the images: 88.933 %
# Epoch 4 started
# Iteration    50 | 6.77039
# Iteration   100 | 6.55550
# Iteration   150 | 6.76506
# Iteration   200 | 6.80421
# Iteration   250 | 6.77926
# IOU Train 0.7854007517050293
# IOU val 0.7743313454360229
# Accuracy of the network on the images: 90.276 %
# Accuracy of the network on the images: 89.683 %
# Epoch 5 started
# Iteration    50 | 6.31456
# Iteration   100 | 6.41253
# Iteration   150 | 6.57713
# Iteration   200 | 6.41794
# Iteration   250 | 6.39237
# IOU Train 0.7831264753499436
# IOU val 0.7735968812539579
# Accuracy of the network on the images: 90.094 %
# Accuracy of the network on the images: 89.592 %
# Epoch 6 started
# Iteration    50 | 6.21222
# Iteration   100 | 6.13945
# Iteration   150 | 6.07514
# Iteration   200 | 6.09649
# Iteration   250 | 6.29533
# IOU Train 0.7967326346842777
# IOU val 0.7808475982634886
# Accuracy of the network on the images: 90.846 %
# Accuracy of the network on the images: 90.020 %
# Epoch 7 started
# Iteration    50 | 5.90616
# Iteration   100 | 5.91507
# Iteration   150 | 5.98513
# Iteration   200 | 5.97047
# Iteration   250 | 5.87294
# IOU Train 0.810657045712396
# IOU val 0.7932845009080985
# Accuracy of the network on the images: 91.369 %
# Accuracy of the network on the images: 90.445 %
# Epoch 8 started
# Iteration    50 | 5.82515
# Iteration   100 | 5.79328
# Iteration   150 | 5.78163
# Iteration   200 | 5.78922
# Iteration   250 | 5.65860
# IOU Train 0.790515974227914
# IOU val 0.7764294403021885
# Accuracy of the network on the images: 90.973 %
# Accuracy of the network on the images: 90.275 %
# Epoch 9 started
# Iteration    50 | 5.66454
# Iteration   100 | 5.72036
# Iteration   150 | 5.68400
# Iteration   200 | 5.57033
# Iteration   250 | 5.59707
# IOU Train 0.82414342836752
# IOU val 0.8020613206026581
# Accuracy of the network on the images: 92.170 %
# Accuracy of the network on the images: 91.057 %
# Epoch 10 started
# Iteration    50 | 5.54200
# Iteration   100 | 5.50267
# Iteration   150 | 5.56744
# Iteration   200 | 5.75838
# Iteration   250 | 5.42643
# IOU Train 0.8119525028208346
# IOU val 0.7901678234071527
# Accuracy of the network on the images: 91.460 %
# Accuracy of the network on the images: 90.324 %
# Epoch 11 started
# Iteration    50 | 5.38215
# Iteration   100 | 5.59969
# Iteration   150 | 5.45026
# Iteration   200 | 5.40048
# Iteration   250 | 5.32445
# IOU Train 0.8342054771109926
# IOU val 0.8091942061253469
# Accuracy of the network on the images: 92.635 %
# Accuracy of the network on the images: 91.380 %
# Epoch 12 started
# Iteration    50 | 5.14727
# Iteration   100 | 5.41471
# Iteration   150 | 5.31678
# Iteration   200 | 5.34748
# Iteration   250 | 5.25978
# IOU Train 0.8417121899292032
# IOU val 0.812402295802497
# Accuracy of the network on the images: 93.002 %
# Accuracy of the network on the images: 91.537 %
# Epoch 13 started
# Iteration    50 | 5.18337
# Iteration   100 | 5.24199
# Iteration   150 | 5.22459
# Iteration   200 | 5.31236
# Iteration   250 | 5.12670
# IOU Train 0.847734557289402
# IOU val 0.8162565730546194
# Accuracy of the network on the images: 93.223 %
# Accuracy of the network on the images: 91.644 %
# Epoch 14 started
# Iteration    50 | 5.01250
# Iteration   100 | 4.94742
# Iteration   150 | 5.17355
# Iteration   200 | 5.16737
# Iteration   250 | 5.11848
# IOU Train 0.8462592842755472
# IOU val 0.8147021425919276
# Accuracy of the network on the images: 93.239 %
# Accuracy of the network on the images: 91.656 %
# Epoch 15 started
# Iteration    50 | 4.85164
# Iteration   100 | 5.09427
# Iteration   150 | 5.03786
# Iteration   200 | 4.99848
# Iteration   250 | 5.14956
# IOU Train 0.8575594696068914
# IOU val 0.8228334286823051
# Accuracy of the network on the images: 93.826 %
# Accuracy of the network on the images: 92.149 %
# Epoch 16 started
# Iteration    50 | 4.83188
# Iteration   100 | 4.81727
# Iteration   150 | 5.00145
# Iteration   200 | 5.03525
# Iteration   250 | 5.03240
# IOU Train 0.857987887031455
# IOU val 0.8197158895954535
# Accuracy of the network on the images: 93.813 %
# Accuracy of the network on the images: 91.943 %
# Epoch 17 started
# Iteration    50 | 4.68591
# Iteration   100 | 5.00895
# Iteration   150 | 4.88034
# Iteration   200 | 4.71828
# Iteration   250 | 4.86148
# IOU Train 0.8595275572384335
# IOU val 0.8203183127764564
# Accuracy of the network on the images: 93.833 %
# Accuracy of the network on the images: 91.901 %
# Epoch 18 started
# Iteration    50 | 4.63824
# Iteration   100 | 4.78097
# Iteration   150 | 4.76847
# Iteration   200 | 4.93901
# Iteration   250 | 4.80765
# IOU Train 0.8559132340555213
# IOU val 0.8137389260574652
# Accuracy of the network on the images: 93.824 %
# Accuracy of the network on the images: 91.793 %
# Epoch 19 started
# Iteration    50 | 4.58088
# Iteration   100 | 4.75560
# Iteration   150 | 4.58034
# Iteration   200 | 4.86481
# Iteration   250 | 4.80077
# IOU Train 0.8676329784917225
# IOU val 0.8215497642510805
# Accuracy of the network on the images: 94.354 %
# Accuracy of the network on the images: 92.172 %
# Epoch 20 started
# Iteration    50 | 4.60117
# Iteration   100 | 4.56460
# Iteration   150 | 4.70384
# Iteration   200 | 4.64327
# Iteration   250 | 4.63604
# IOU Train 0.8544149191809058
# IOU val 0.8087627860378883
# Accuracy of the network on the images: 93.481 %
# Accuracy of the network on the images: 91.144 %
# Epoch 21 started
# Iteration    50 | 4.47092
# Iteration   100 | 4.52409
# Iteration   150 | 4.50322
# Iteration   200 | 4.46983
# Iteration   250 | 4.68456
# IOU Train 0.8753047680147964
# IOU val 0.8235949172170769
# Accuracy of the network on the images: 94.606 %
# Accuracy of the network on the images: 92.106 %
# Epoch 22 started
# Iteration    50 | 4.38382
# Iteration   100 | 4.44087
# Iteration   150 | 4.32975
# Iteration   200 | 4.59103
# Iteration   250 | 4.55299
# IOU Train 0.8775912550553095
# IOU val 0.8211909641969901
# Accuracy of the network on the images: 94.793 %
# Accuracy of the network on the images: 92.111 %
# Epoch 23 started
# Iteration    50 | 4.27259
# Iteration   100 | 4.44757
# Iteration   150 | 4.51998
# Iteration   200 | 4.34779
# Iteration   250 | 4.44526
# IOU Train 0.8742597727934143
# IOU val 0.8171429581676699
# Accuracy of the network on the images: 94.553 %
# Accuracy of the network on the images: 91.751 %
# Epoch 24 started
# Iteration    50 | 4.17951
# Iteration   100 | 4.37525
# Iteration   150 | 4.42451
# Iteration   200 | 4.50692
# Iteration   250 | 4.28801
# IOU Train 0.8866786861975386
# IOU val 0.8258052397539519
# Accuracy of the network on the images: 95.243 %
# Accuracy of the network on the images: 92.404 %
# Epoch 25 started
# Iteration    50 | 4.09519
# Iteration   100 | 4.29930
# Iteration   150 | 4.36514
# Iteration   200 | 4.20495
# Iteration   250 | 4.34768
# IOU Train 0.8901921816213498
# IOU val 0.8258361935153599
# Accuracy of the network on the images: 95.384 %
# Accuracy of the network on the images: 92.376 %
# Epoch 26 started
# Iteration    50 | 4.10272
# Iteration   100 | 4.19386
# Iteration   150 | 4.32158
# Iteration   200 | 4.21059
# Iteration   250 | 4.29380
# IOU Train 0.8872392690204878
# IOU val 0.8219354128870635
# Accuracy of the network on the images: 95.128 %
# Accuracy of the network on the images: 91.947 %
# Epoch 27 started
# Iteration    50 | 4.14246
# Iteration   100 | 4.17333
# Iteration   150 | 4.12939
# Iteration   200 | 4.05150
# Iteration   250 | 4.21047
# IOU Train 0.8876367436210619
# IOU val 0.8237367817880904
# Accuracy of the network on the images: 95.185 %
# Accuracy of the network on the images: 92.109 %
# Epoch 28 started
# Iteration    50 | 4.02542
# Iteration   100 | 4.11587
# Iteration   150 | 4.09981
# Iteration   200 | 4.08239
# Iteration   250 | 4.22624
# IOU Train 0.8988854080771833
# IOU val 0.8286896469705212
# Accuracy of the network on the images: 95.716 %
# Accuracy of the network on the images: 92.383 %
# Epoch 29 started
# Iteration    50 | 4.00559
# Iteration   100 | 4.04138
# Iteration   150 | 3.98981
# Iteration   200 | 3.97738
# Iteration   250 | 4.27898
# IOU Train 0.8998631008267735
# IOU val 0.828035391018789
# Accuracy of the network on the images: 95.796 %
# Accuracy of the network on the images: 92.444 %
# Epoch 30 started
# Iteration    50 | 3.87794
# Iteration   100 | 3.91442
# Iteration   150 | 3.99532
# Iteration   200 | 4.03635
# Iteration   250 | 4.09066
# IOU Train 0.9003075227122638
# IOU val 0.8296592224236063
# Accuracy of the network on the images: 95.832 %
# Accuracy of the network on the images: 92.566 %
# Epoch 31 started
# Iteration    50 | 3.88194
# Iteration   100 | 3.89587
# Iteration   150 | 3.94274
# Iteration   200 | 3.97867
# Iteration   250 | 3.95279
# IOU Train 0.902431152042305
# IOU val 0.8265007982747488
# Accuracy of the network on the images: 95.911 %
# Accuracy of the network on the images: 92.357 %
# Epoch 32 started
# Iteration    50 | 3.77578
# Iteration   100 | 3.77700
# Iteration   150 | 4.00257
# Iteration   200 | 3.89597
# Iteration   250 | 4.08162
# IOU Train 0.9003728021566005
# IOU val 0.826348873985042
# Accuracy of the network on the images: 95.795 %
# Accuracy of the network on the images: 92.306 %
# Epoch 33 started
# Iteration    50 | 3.78946
# Iteration   100 | 3.89050
# Iteration   150 | 3.84809
# Iteration   200 | 3.84888
# Iteration   250 | 3.96455
# IOU Train 0.8992474929367291
# IOU val 0.8210813076850159
# Accuracy of the network on the images: 95.817 %
# Accuracy of the network on the images: 92.235 %
# Epoch 34 started
# Iteration    50 | 3.73716
# Iteration   100 | 3.74280
# Iteration   150 | 3.75737
# Iteration   200 | 3.89362
# Iteration   250 | 3.92926
# IOU Train 0.9089166368314368
# IOU val 0.8284176582498131
# Accuracy of the network on the images: 96.218 %
# Accuracy of the network on the images: 92.537 %
# Epoch 35 started
# Iteration    50 | 3.66548
# Iteration   100 | 3.77662
# Iteration   150 | 3.73241
# Iteration   200 | 3.79749
# Iteration   250 | 3.79318
# IOU Train 0.9111638969809512
# IOU val 0.8302144195749809
# Accuracy of the network on the images: 96.291 %
# Accuracy of the network on the images: 92.542 %
# Epoch 36 started
# Iteration    50 | 3.67171
# Iteration   100 | 3.68269
# Iteration   150 | 3.85189
# Iteration   200 | 3.76524
# Iteration   250 | 3.72206
# IOU Train 0.9150873727342208
# IOU val 0.8321177463011054
# Accuracy of the network on the images: 96.486 %
# Accuracy of the network on the images: 92.692 %
# Epoch 37 started
# Iteration    50 | 3.56705
# Iteration   100 | 3.54214
# Iteration   150 | 3.69481
# Iteration   200 | 3.73779
# Iteration   250 | 3.84703
# IOU Train 0.9131977969204441
# IOU val 0.8279891265324183
# Accuracy of the network on the images: 96.384 %
# Accuracy of the network on the images: 92.432 %
# Epoch 38 started
# Iteration    50 | 3.65881
# Iteration   100 | 3.57927
# Iteration   150 | 3.60114
# Iteration   200 | 3.58385
# Iteration   250 | 3.75773
# IOU Train 0.909865182241478
# IOU val 0.824555223709546
# Accuracy of the network on the images: 96.263 %
# Accuracy of the network on the images: 92.298 %
# Epoch 39 started
# Iteration    50 | 3.58404
# Iteration   100 | 3.54510
# Iteration   150 | 3.55709
# Iteration   200 | 3.64867
# Iteration   250 | 3.82523
# IOU Train 0.9137653071224656
# IOU val 0.827114567522018
# Accuracy of the network on the images: 96.427 %
# Accuracy of the network on the images: 92.427 %
# Epoch 40 started
# Iteration    50 | 3.46370
# Iteration   100 | 3.70377
# Iteration   150 | 3.58023
# Iteration   200 | 3.65679
# Iteration   250 | 3.53429
# IOU Train 0.9090790214424183
# IOU val 0.8212723697414162
# Accuracy of the network on the images: 96.241 %
# Accuracy of the network on the images: 92.225 %
# Epoch 41 started
# Iteration    50 | 3.56387
# Iteration   100 | 3.48133
# Iteration   150 | 3.52365
# Iteration   200 | 3.52491
# Iteration   250 | 3.75012
# IOU Train 0.9127824584560047
# IOU val 0.8243760037510944
# Accuracy of the network on the images: 96.413 %
# Accuracy of the network on the images: 92.426 %
# Epoch 42 started
# Iteration    50 | 3.41710
# Iteration   100 | 3.46125
# Iteration   150 | 3.55938
# Iteration   200 | 3.56416
# Iteration   250 | 3.55969
# IOU Train 0.917654358394113
# IOU val 0.8277796648664209
# Accuracy of the network on the images: 96.567 %
# Accuracy of the network on the images: 92.360 %
# Epoch 43 started
# Iteration    50 | 3.48144
# Iteration   100 | 3.56720
# Iteration   150 | 3.44212
# Iteration   200 | 3.52908
# Iteration   250 | 3.45118
# IOU Train 0.9216078644065873
# IOU val 0.8279484249927533
# Accuracy of the network on the images: 96.759 %
# Accuracy of the network on the images: 92.449 %
# Epoch 44 started
# Iteration    50 | 3.41998
# Iteration   100 | 3.44734
# Iteration   150 | 3.40119
# Iteration   200 | 3.50713
# Iteration   250 | 3.46219
# IOU Train 0.91752624683448
# IOU val 0.822347925215775
# Accuracy of the network on the images: 96.620 %
# Accuracy of the network on the images: 92.312 %
# Epoch 45 started
# Iteration    50 | 3.48733
# Iteration   100 | 3.42266
# Iteration   150 | 3.40396
# Iteration   200 | 3.39595
# Iteration   250 | 3.52033
# IOU Train 0.9199033508661152
# IOU val 0.8263538319381748
# Accuracy of the network on the images: 96.694 %
# Accuracy of the network on the images: 92.433 %
# Epoch 46 started
# Iteration    50 | 3.29541
# Iteration   100 | 3.35705
# Iteration   150 | 3.36429
# Iteration   200 | 3.38213
# Iteration   250 | 3.50997
# IOU Train 0.9150042757446932
# IOU val 0.818763276579618
# Accuracy of the network on the images: 96.523 %
# Accuracy of the network on the images: 92.217 %
# Epoch 47 started
# Iteration    50 | 3.28079
# Iteration   100 | 3.35131
# Iteration   150 | 3.42634
# Iteration   200 | 3.36428
# Iteration   250 | 3.46208
# IOU Train 0.9163071761510355
# IOU val 0.824758873212102
# Accuracy of the network on the images: 96.562 %
# Accuracy of the network on the images: 92.432 %
# Epoch 48 started
# Iteration    50 | 3.29988
# Iteration   100 | 3.32395
# Iteration   150 | 3.23516
# Iteration   200 | 3.47950
# Iteration   250 | 3.47704
# IOU Train 0.9222076085028639
# IOU val 0.8282092428003278
# Accuracy of the network on the images: 96.792 %
# Accuracy of the network on the images: 92.497 %
# Epoch 49 started
# Iteration    50 | 3.27142
# Iteration   100 | 3.32308
# Iteration   150 | 3.27921
# Iteration   200 | 3.36923
# Iteration   250 | 3.35988
# IOU Train 0.9247321777015278
# IOU val 0.827785198526652
# Accuracy of the network on the images: 96.881 %
# Accuracy of the network on the images: 92.371 %
# Epoch 50 started
# Iteration    50 | 3.23281
# Iteration   100 | 3.38550
# Iteration   150 | 3.40343
# Iteration   200 | 3.37185
# Iteration   250 | 3.37998
# IOU Train 0.9242374004902862
# IOU val 0.8275342259645165
# Accuracy of the network on the images: 96.889 %
# Accuracy of the network on the images: 92.506 %
# Epoch 51 started
# Iteration    50 | 3.23861
# Iteration   100 | 3.22670
# Iteration   150 | 3.44444
# Iteration   200 | 3.38556
# Iteration   250 | 3.27060
# IOU Train 0.9275748222148985
# IOU val 0.829233599469327
# Accuracy of the network on the images: 96.994 %
# Accuracy of the network on the images: 92.397 %
# Epoch 52 started
# Iteration    50 | 3.15195
# Iteration   100 | 3.25681
# Iteration   150 | 3.26650
# Iteration   200 | 3.43759
# Iteration   250 | 3.25282
# IOU Train 0.9274022630808947
# IOU val 0.8284440977960108
# Accuracy of the network on the images: 97.014 %
# Accuracy of the network on the images: 92.509 %
# Epoch 53 started
# Iteration    50 | 3.13957
# Iteration   100 | 3.26572
# Iteration   150 | 3.22740
# Iteration   200 | 3.34523
# Iteration   250 | 3.22840
# IOU Train 0.9233462105209493
# IOU val 0.8228314716287444
# Accuracy of the network on the images: 96.854 %
# Accuracy of the network on the images: 92.294 %
# Epoch 54 started
# Iteration    50 | 3.18331
# Iteration   100 | 3.15731
# Iteration   150 | 3.17694
# Iteration   200 | 3.29613
# Iteration   250 | 3.35772
# IOU Train 0.9274705886614931
# IOU val 0.827573026949346
# Accuracy of the network on the images: 97.007 %
# Accuracy of the network on the images: 92.408 %
# Epoch 55 started
# Iteration    50 | 3.13291
# Iteration   100 | 3.23301
# Iteration   150 | 3.20432
# Iteration   200 | 3.18763
# Iteration   250 | 3.23955
# IOU Train 0.930322642188409
# IOU val 0.8283927321699076
# Accuracy of the network on the images: 97.143 %
# Accuracy of the network on the images: 92.534 %
# Epoch 56 started
# Iteration    50 | 3.17429
# Iteration   100 | 3.18210
# Iteration   150 | 3.04415
# Iteration   200 | 3.26514
# Iteration   250 | 3.33953
# IOU Train 0.9264547972823938
# IOU val 0.8244657639577442
# Accuracy of the network on the images: 96.989 %
# Accuracy of the network on the images: 92.396 %
# Epoch 57 started
# Iteration    50 | 3.22705
# Iteration   100 | 3.13804
# Iteration   150 | 3.13250
# Iteration   200 | 3.21644
# Iteration   250 | 3.18588
# IOU Train 0.9270071351141334
# IOU val 0.8237705566772926
# Accuracy of the network on the images: 97.019 %
# Accuracy of the network on the images: 92.400 %
# Epoch 58 started
# Iteration    50 | 3.12406
# Iteration   100 | 3.11116
# Iteration   150 | 3.14349
# Iteration   200 | 3.22949
# Iteration   250 | 3.14980
# IOU Train 0.918284674992431
# IOU val 0.8196846699975955
# Accuracy of the network on the images: 96.584 %
# Accuracy of the network on the images: 91.943 %
# Epoch 59 started
# Iteration    50 | 3.01712
# Iteration   100 | 3.13465
# Iteration   150 | 3.11352
# Iteration   200 | 3.20419
# Iteration   250 | 3.16138
# IOU Train 0.9161429988852996
# IOU val 0.8124238106960124
# Accuracy of the network on the images: 96.589 %
# Accuracy of the network on the images: 92.020 %
# Epoch 60 started
# Iteration    50 | 3.15003
# Iteration   100 | 3.12372
# Iteration   150 | 3.16319
# Iteration   200 | 3.19722
# Iteration   250 | 3.15812
# IOU Train 0.9294812084560613
# IOU val 0.8286398945583084
# Accuracy of the network on the images: 97.107 %
# Accuracy of the network on the images: 92.507 %
# Epoch 61 started
# Iteration    50 | 3.06207
# Iteration   100 | 3.22799
# Iteration   150 | 3.14318
# Iteration   200 | 3.19809
# Iteration   250 | 3.17660
# IOU Train 0.9311470041756587
# IOU val 0.8293565477849556
# Accuracy of the network on the images: 97.176 %
# Accuracy of the network on the images: 92.554 %
# Epoch 62 started
# Iteration    50 | 3.04825
# Iteration   100 | 3.06590
# Iteration   150 | 3.23142
# Iteration   200 | 3.10186
# Iteration   250 | 3.11696
# IOU Train 0.9336657481286748
# IOU val 0.8291828825219906
# Accuracy of the network on the images: 97.285 %
# Accuracy of the network on the images: 92.540 %
# Epoch 63 started
# Iteration    50 | 3.05038
# Iteration   100 | 3.08861
# Iteration   150 | 3.08837
# Iteration   200 | 3.07432
# Iteration   250 | 3.07251
# IOU Train 0.9307197873472156
# IOU val 0.8262495756683086
# Accuracy of the network on the images: 97.147 %
# Accuracy of the network on the images: 92.310 %
# Epoch 64 started
# Iteration    50 | 2.99793
# Iteration   100 | 3.05390
# Iteration   150 | 3.11021
# Iteration   200 | 3.04452
# Iteration   250 | 3.12307
# IOU Train 0.9276954722204424
# IOU val 0.8266298548814475
# Accuracy of the network on the images: 97.053 %
# Accuracy of the network on the images: 92.541 %
# Epoch 65 started
# Iteration    50 | 2.93013
# Iteration   100 | 3.02282
# Iteration   150 | 3.01222
# Iteration   200 | 3.11190
# Iteration   250 | 3.19868
# IOU Train 0.9339129615841119
# IOU val 0.8315728757627538
# Accuracy of the network on the images: 97.290 %
# Accuracy of the network on the images: 92.645 %
# Epoch 66 started
# Iteration    50 | 2.98742
# Iteration   100 | 2.96423
# Iteration   150 | 3.07414
# Iteration   200 | 3.07344
# Iteration   250 | 3.13844
# IOU Train 0.9310950526002558
# IOU val 0.8226385088275643
# Accuracy of the network on the images: 97.195 %
# Accuracy of the network on the images: 92.389 %
# Epoch 67 started
# Iteration    50 | 3.02543
# Iteration   100 | 3.06699
# Iteration   150 | 3.02986
# Iteration   200 | 3.01995
# Iteration   250 | 3.06072
# IOU Train 0.9358496695644951
# IOU val 0.8299115538328765
# Accuracy of the network on the images: 97.376 %
# Accuracy of the network on the images: 92.607 %
# Epoch 68 started
# Iteration    50 | 2.95192
# Iteration   100 | 3.00597
# Iteration   150 | 2.99726
# Iteration   200 | 3.05814
# Iteration   250 | 3.14534
# IOU Train 0.9340696471963592
# IOU val 0.8279467512180336
# Accuracy of the network on the images: 97.303 %
# Accuracy of the network on the images: 92.501 %
# Epoch 69 started
# Iteration    50 | 2.93822
# Iteration   100 | 3.02337
# Iteration   150 | 3.08379
# Iteration   200 | 2.93539
# Iteration   250 | 3.08141
# IOU Train 0.935152059240254
# IOU val 0.8306908380277482
# Accuracy of the network on the images: 97.344 %
# Accuracy of the network on the images: 92.598 %
# Epoch 70 started
# Iteration    50 | 2.94369
# Iteration   100 | 2.92039
# Iteration   150 | 2.97105
# Iteration   200 | 2.96480
# Iteration   250 | 3.07940
# IOU Train 0.933876327927502
# IOU val 0.8265315050238689
# Accuracy of the network on the images: 97.308 %
# Accuracy of the network on the images: 92.507 %
# Epoch 71 started
# Iteration    50 | 2.89325
# Iteration   100 | 3.05996
# Iteration   150 | 3.03454
# Iteration   200 | 3.05602
# Iteration   250 | 2.97415
# IOU Train 0.9356924539078032
# IOU val 0.8297712610998844
# Accuracy of the network on the images: 97.381 %
# Accuracy of the network on the images: 92.659 %
# Epoch 72 started
# Iteration    50 | 2.93567
# Iteration   100 | 2.84827
# Iteration   150 | 2.88542
# Iteration   200 | 3.03832
# Iteration   250 | 3.02087
# IOU Train 0.9369308971745656
# IOU val 0.8305018366601602
# Accuracy of the network on the images: 97.414 %
# Accuracy of the network on the images: 92.555 %
# Epoch 73 started
# Iteration    50 | 2.94662
# Iteration   100 | 2.94672
# Iteration   150 | 2.97381
# Iteration   200 | 2.99968
# Iteration   250 | 3.00042
# IOU Train 0.9375322494875618
# IOU val 0.8286125509585074
# Accuracy of the network on the images: 97.445 %
# Accuracy of the network on the images: 92.504 %
# Epoch 74 started
# Iteration    50 | 2.84009
# Iteration   100 | 2.99496
# Iteration   150 | 2.97330
# Iteration   200 | 2.92687
# Iteration   250 | 2.93685
# IOU Train 0.9355274111361835
# IOU val 0.826377936446681
# Accuracy of the network on the images: 97.371 %
# Accuracy of the network on the images: 92.472 %
# Epoch 75 started
# Iteration    50 | 2.90987
# Iteration   100 | 2.88050
# Iteration   150 | 2.84583
# Iteration   200 | 2.94167
# Iteration   250 | 2.99177
# IOU Train 0.9333683683255718
# IOU val 0.8240503734262381
# Accuracy of the network on the images: 97.282 %
# Accuracy of the network on the images: 92.361 %
# Epoch 76 started
# Iteration    50 | 2.83955
# Iteration   100 | 2.90597
# Iteration   150 | 2.91636
# Iteration   200 | 2.95028
# Iteration   250 | 3.10581
# IOU Train 0.9326494463480208
# IOU val 0.8247539463746971
# Accuracy of the network on the images: 97.229 %
# Accuracy of the network on the images: 92.252 %
# Epoch 77 started
# Iteration    50 | 2.86141
# Iteration   100 | 2.93032
# Iteration   150 | 2.98768
# Iteration   200 | 2.98176
# Iteration   250 | 2.84465
# IOU Train 0.9357668762933802
# IOU val 0.826424768757607
# Accuracy of the network on the images: 97.384 %
# Accuracy of the network on the images: 92.527 %
# Epoch 78 started
# Iteration    50 | 2.92872
# Iteration   100 | 2.82108
# Iteration   150 | 2.93248
# Iteration   200 | 2.97529
# Iteration   250 | 2.98477
# IOU Train 0.9377492860940557
# IOU val 0.8295062348333131
# Accuracy of the network on the images: 97.457 %
# Accuracy of the network on the images: 92.555 %
# Epoch 79 started
# Iteration    50 | 2.88353
# Iteration   100 | 2.88581
# Iteration   150 | 2.87851
# Iteration   200 | 2.89693
# Iteration   250 | 2.90160
# IOU Train 0.9366866378473361
# IOU val 0.8311182011107738
# Accuracy of the network on the images: 97.416 %
# Accuracy of the network on the images: 92.644 %
# Epoch 80 started
# Iteration    50 | 2.80579
# Iteration   100 | 2.90766
# Iteration   150 | 2.89798
# Iteration   200 | 2.87312
# Iteration   250 | 2.94364
# IOU Train 0.9319819240173406
# IOU val 0.8182166694410962
# Accuracy of the network on the images: 97.235 %
# Accuracy of the network on the images: 92.189 %
# Epoch 81 started
# Iteration    50 | 2.82995
# Iteration   100 | 2.88333
# Iteration   150 | 2.81488
# Iteration   200 | 2.86290
# Iteration   250 | 2.92373
# IOU Train 0.9399952277516179
# IOU val 0.831942599029918
# Accuracy of the network on the images: 97.554 %
# Accuracy of the network on the images: 92.666 %
# Epoch 82 started
# Iteration    50 | 2.81523
# Iteration   100 | 2.76286
# Iteration   150 | 2.85315
# Iteration   200 | 2.87883
# Iteration   250 | 2.90463
# IOU Train 0.9316698061045917
# IOU val 0.8217074136286369
# Accuracy of the network on the images: 97.188 %
# Accuracy of the network on the images: 92.107 %
# Epoch 83 started
# Iteration    50 | 2.85046
# Iteration   100 | 2.86076
# Iteration   150 | 2.77527
# Iteration   200 | 2.80523
# Iteration   250 | 2.89968
# IOU Train 0.9391907649334048
# IOU val 0.8291722963468893
# Accuracy of the network on the images: 97.521 %
# Accuracy of the network on the images: 92.568 %
# Epoch 84 started
# Iteration    50 | 2.81949
# Iteration   100 | 2.89278
# Iteration   150 | 2.89826
# Iteration   200 | 2.85439
# Iteration   250 | 2.88519
# IOU Train 0.9408212704855596
# IOU val 0.8297167111947175
# Accuracy of the network on the images: 97.576 %
# Accuracy of the network on the images: 92.469 %
# Epoch 85 started
# Iteration    50 | 2.80957
# Iteration   100 | 2.82348
# Iteration   150 | 2.89686
# Iteration   200 | 2.78212
# Iteration   250 | 2.90537
# IOU Train 0.9394818219189011
# IOU val 0.8289063815461408
# Accuracy of the network on the images: 97.526 %
# Accuracy of the network on the images: 92.482 %
# Epoch 86 started
# Iteration    50 | 2.84941
# Iteration   100 | 2.84281
# Iteration   150 | 2.78813
# Iteration   200 | 2.85706
# Iteration   250 | 2.82185
# IOU Train 0.941236726145199
# IOU val 0.8305948365989811
# Accuracy of the network on the images: 97.606 %
# Accuracy of the network on the images: 92.631 %
# Epoch 87 started
# Iteration    50 | 2.80387
# Iteration   100 | 2.85525
# Iteration   150 | 2.85127
# Iteration   200 | 2.82171
# Iteration   250 | 2.87009
# IOU Train 0.9343600336165601
# IOU val 0.8225192985818366
# Accuracy of the network on the images: 97.328 %
# Accuracy of the network on the images: 92.315 %
# Epoch 88 started
# Iteration    50 | 2.82120
# Iteration   100 | 2.75521
# Iteration   150 | 2.77591
# Iteration   200 | 2.88415
# Iteration   250 | 2.76231
# IOU Train 0.940723837305458
# IOU val 0.8279299424994069
# Accuracy of the network on the images: 97.583 %
# Accuracy of the network on the images: 92.525 %
# Epoch 89 started
# Iteration    50 | 2.79120
# Iteration   100 | 2.77179
# Iteration   150 | 2.83709
# Iteration   200 | 2.81449
# Iteration   250 | 2.77345
# IOU Train 0.93813649849596
# IOU val 0.8245987958437958
# Accuracy of the network on the images: 97.485 %
# Accuracy of the network on the images: 92.428 %
# Epoch 90 started
# Iteration    50 | 2.77220
# Iteration   100 | 2.74895
# Iteration   150 | 2.84962
# Iteration   200 | 2.83147
# Iteration   250 | 2.79005
# IOU Train 0.9386529937086565
# IOU val 0.8253357252645187
# Accuracy of the network on the images: 97.507 %
# Accuracy of the network on the images: 92.473 %
# Epoch 91 started
# Iteration    50 | 2.72959
# Iteration   100 | 2.81816
# Iteration   150 | 2.74580
# Iteration   200 | 2.83730
# Iteration   250 | 2.83317
# IOU Train 0.940004061100363
# IOU val 0.8287778437327331
# Accuracy of the network on the images: 97.548 %
# Accuracy of the network on the images: 92.502 %
# Epoch 92 started
# Iteration    50 | 2.73166
# Iteration   100 | 2.67728
# Iteration   150 | 2.88939
# Iteration   200 | 2.81548
# Iteration   250 | 2.77396
# IOU Train 0.9418003550362216
# IOU val 0.8288356266323159
# Accuracy of the network on the images: 97.634 %
# Accuracy of the network on the images: 92.560 %
# Epoch 93 started
# Iteration    50 | 2.66706
# Iteration   100 | 2.74794
# Iteration   150 | 2.71202
# Iteration   200 | 2.77863
# Iteration   250 | 2.84005
# IOU Train 0.9368830754763721
# IOU val 0.8225974977033117
# Accuracy of the network on the images: 97.442 %
# Accuracy of the network on the images: 92.374 %
# Epoch 94 started
# Iteration    50 | 2.73050
# Iteration   100 | 2.81215
# Iteration   150 | 2.75027
# Iteration   200 | 2.82694
# Iteration   250 | 2.80342
# IOU Train 0.9412308674494448
# IOU val 0.8268460524229013
# Accuracy of the network on the images: 97.613 %
# Accuracy of the network on the images: 92.509 %
# Epoch 95 started
# Iteration    50 | 2.73439
# Iteration   100 | 2.77169
# Iteration   150 | 2.85349
# Iteration   200 | 2.81777
# Iteration   250 | 2.78103
# IOU Train 0.938543958965054
# IOU val 0.825866286761292
# Accuracy of the network on the images: 97.510 %
# Accuracy of the network on the images: 92.526 %
# Epoch 96 started
# Iteration    50 | 2.67954
# Iteration   100 | 2.76515
# Iteration   150 | 2.73858
# Iteration   200 | 2.81559
# Iteration   250 | 2.82961
# IOU Train 0.9395911027232122
# IOU val 0.8250792647886722
# Accuracy of the network on the images: 97.550 %
# Accuracy of the network on the images: 92.426 %
# Epoch 97 started
# Iteration    50 | 2.65507
# Iteration   100 | 2.70298
# Iteration   150 | 2.77806
# Iteration   200 | 2.82225
# Iteration   250 | 2.79240
# IOU Train 0.9420438737249486
# IOU val 0.8277435527679683
# Accuracy of the network on the images: 97.648 %
# Accuracy of the network on the images: 92.580 %
# Epoch 98 started
# Iteration    50 | 2.81635
# Iteration   100 | 2.77001
# Iteration   150 | 2.63990
# Iteration   200 | 2.73806
# Iteration   250 | 2.74080
# IOU Train 0.9399038794282801
# IOU val 0.8260051053404258
# Accuracy of the network on the images: 97.546 %
# Accuracy of the network on the images: 92.321 %
# Epoch 99 started
# Iteration    50 | 2.73480
# Iteration   100 | 2.66901
# Iteration   150 | 2.79329
# Iteration   200 | 2.76899
# Iteration   250 | 2.86048
# IOU Train 0.9414357937808067
# IOU val 0.8301212007544694
# Accuracy of the network on the images: 97.620 %
# Accuracy of the network on the images: 92.604 %
# Epoch 100 started
# Iteration    50 | 2.65370
# Iteration   100 | 2.76279
# Iteration   150 | 2.68640
# Iteration   200 | 2.69106
# Iteration   250 | 2.73817
# IOU Train 0.9376327693588203
# IOU val 0.8212646310880465
# Accuracy of the network on the images: 97.461 %
# Accuracy of the network on the images: 92.235 %

# %%
PATH = './CustomNet-64-v4-refinenet/100-checkpoint'
checkpoint = torch.load(PATH)
model.load_state_dict(checkpoint['model-state-dict'])
refine_model.load_state_dict(checkpoint['refinemodel-state-dict'])
# Out:
# <All keys matched successfully>

# %%
np.argmax(np.array(checkpoint['val_acc']))
# Out:
# 35

# %%
accuracy(model, refine_model, test_loader)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3063: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# Accuracy of the network on the images: 89.438 %
# (0.31266180335716076, 89.43794829647341)

# %%
mIoU(model, refine_model, test_loader, 2)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3063: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# 0.6780414692869026

# %%
train_acc = checkpoint['train_acc']
train_loss = checkpoint['train_loss']
val_acc = checkpoint['val_acc']
val_loss = checkpoint['val_loss']

plt.plot(list(range(checkpoint['epoch'])), train_acc)
plt.plot(list(range(checkpoint['epoch'])), val_acc)
plt.legend(['train accuracy', 'val accuracy'], loc='lower right')
plt.show()

# %%
plt.plot(list(range(checkpoint['epoch'])), train_loss)
plt.plot(list(range(checkpoint['epoch'])), val_loss)
plt.legend(['train loss', 'val loss'], loc='upper right')
plt.show()

# %%
colors = [
    np.array([255,255,255], dtype=np.uint8),
    np.array([0,0,0], dtype=np.uint8),
]

# %%
itr = iter(test_loader)

# %%
model.eval()
img, lab = itr.next()
_,_,_,outputs = model(img.to(device))
outputs = refine_model(outputs)
_,predicted = torch.max(outputs, 1)

input, lab, pred = img[0], lab[0], predicted[0].cpu().detach()
print(f'{input.size()} | {lab.size()} | {pred.size()}')

img_size = input.shape[-1]
input_img = np.zeros((img_size, img_size, 3))
input_img[:, :, 0] = input[0]
input_img[:, :, 1] = input[1]
input_img[:, :, 2] = input[2]

input_img = (255 * input_img)
print(input_img.shape)
input_img = Image.fromarray(input_img.astype('uint8'), mode='RGB')
ground_truth = np.zeros((img_size, img_size, 3), dtype=np.uint8)
predicted = np.zeros((img_size, img_size, 3), dtype=np.uint8)

for i in range(img_size):
    for j in range(img_size):
        ground_truth[i][j] = colors[lab[i][j]]
        predicted[i][j] = colors[pred[i][j]]

ground_truth = Image.fromarray(ground_truth).convert('RGB')
predicted = Image.fromarray(predicted).convert('RGB')

display(input_img)
# Out:
# torch.Size([3, 64, 64]) | torch.Size([64, 64]) | torch.Size([64, 64])
# (64, 64, 3)
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3063: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F7A3117B390>

# %%
display(ground_truth)
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F7A31AF8358>

# %%
display(predicted)
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F7A97878BE0>
